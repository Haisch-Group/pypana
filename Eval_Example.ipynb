# %%
# -*- coding: utf-8 -*-
# Eval Info
from datetime import datetime
date = datetime.today().strftime('%Y-%m-%d')
user = "KevinMaier"
print(date, user)
# Out:
# 2025-08-23 KevinMaier

# %%
run particle_analysis.py
